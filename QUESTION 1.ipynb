# %%
from array import array
ar1 = array('b', [1,2,3,4])
print("Original array:")
print(ar1)
print("Array to list:")
print(ar1.tolist())
# Out:
# Original array:
# array('b', [1, 2, 3, 4])
# Array to list:
# [1, 2, 3, 4]
